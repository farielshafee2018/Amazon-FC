# %% [markdown]
# <a href="https://colab.research.google.com/github/farielshafee2018/Amazon-FC/blob/main/Amazon_Text_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# This notebook cleans Glassdoor reviews for Amazon Warehouse work prior to sentiment analysis

# %%
import nltk
import string
from nltk.corpus import stopwords
nltk.download('stopwords')

def clean_text(text):
    if pd.isnull(text):
        return ""
    tokens = text.lower().translate(str.maketrans('', '', string.punctuation)).split()
    return ' '.join([word for word in tokens if word not in stopwords.words('english')])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data = pd.read_excel("/content/youtube_review_dirty.xlsx")

# %%
data.head()
# Out:
#    S No.                                               Link Upload Date  \
# 0    NaN        https://www.youtube.com/watch?v=bU1xOB4oT8E  2025-01-06
# 1    2.0        https://www.youtube.com/watch?v=FnK9JEL62x8  2024-10-03
# 2    3.0     https://www.youtube.com/watch?v=oK7iF-zCWPc321  2024-12-16
# 3    4.0        https://www.youtube.com/watch?v=womH-sRkxXY  2025-07-10
# 4    5.0  https://www.youtube.com/watch?v=OreJan 6, 2025...         NaT
#
#    Views  Likes  Comments                         Transcript/Transcript Link
# 0   1079     83         0  I hate my job. Most physical job in the buildi...
# 1    503     12         0                knocked my camera, eternal transfer
# 2    321      5         0  11 to 12 hour shift, draining, strips creativi...
# 3     65      3         0  tedious job at same speed for 6 to 7 hrs a day...
# 4    863     43         2  standing on my feet for hours. My leg hurts.  ...

# %%
data["transcript_cleaned"]=data["Transcript/Transcript Link"].apply(lambda x: clean_text(x))

# %%
data.head()
# Out:
#    S No.                                               Link Upload Date  \
# 0    NaN        https://www.youtube.com/watch?v=bU1xOB4oT8E  2025-01-06
# 1    2.0        https://www.youtube.com/watch?v=FnK9JEL62x8  2024-10-03
# 2    3.0     https://www.youtube.com/watch?v=oK7iF-zCWPc321  2024-12-16
# 3    4.0        https://www.youtube.com/watch?v=womH-sRkxXY  2025-07-10
# 4    5.0  https://www.youtube.com/watch?v=OreJan 6, 2025...         NaT
#
#    Views  Likes  Comments                         Transcript/Transcript Link  \
# 0   1079     83         0  I hate my job. Most physical job in the buildi...
# 1    503     12         0                knocked my camera, eternal transfer
# 2    321      5         0  11 to 12 hour shift, draining, strips creativi...
# 3     65      3         0  tedious job at same speed for 6 to 7 hrs a day...
# 4    863     43         2  standing on my feet for hours. My leg hurts.  ...
#
#                                   transcript_cleaned
# ...

# %%
data.to_csv("youtube_data_cleaned.csv")
